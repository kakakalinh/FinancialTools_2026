# %% [markdown]
# <center>
# <img src="../images/fscampus_small2.png" width="1200"/>
# </center>
#
#
# ***Finance I (OFIN)-SS2026***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer.cayirli@vgu.edu.vn
#
# ---

# %% [markdown]
# ## Lecture 07
# ---

# %% [markdown]
# ### Outline
# *   Risk and Return
#     *   Market Efficiency
#     *   Capital markets and the pricing of risk
#
#
# ---

# %%
import subprocess
import webbrowser
import os
from IPython.display import HTML
video_path = r"..\videos\israel_iran_tensions.mp4"
def create_video_link(video_path):
    abs_path = os.path.abspath(video_path).replace('\\', '/')
    file_url = f"file:///{abs_path}"
    
    html = f"""
    <div style="border: 2px solid #ccc; padding: 20px; text-align: center;">
        <h3>Video: {os.path.basename(video_path)}</h3>
        <p>VS Code Jupyter blocks video controls. Click link to open in your default player:</p>
        
        <button onclick="window.open('{file_url}')" style="padding: 10px 20px; font-size: 16px;">
            Open Video
        </button>
    </div>
    """
    return HTML(html)

create_video_link(video_path)
# Out:
#     <div style="border: 2px solid #ccc; padding: 20px; text-align: center;">
#         <h3>Video: israel_iran_tensions.mp4</h3>
#         <p>VS Code Jupyter blocks video controls. Click link to open in your default player:</p>
#
#         <button onclick="window.open('file:///c:/Users/Asus/My Drive/GitHubProjects/Financial_Tools_OFIN_SS2026/videos/israel_iran_tensions.mp4')" style="padding: 10px 20px; font-size: 16px;">
#             Open Video
#         </button>
#     </div>

# %% [markdown]
# ### Capital markets and the pricing of risk
#
# <div style="display: flex; justify-content: space-around;">
#     <img src="..\figures\pricing_risk_01.png" style="width: 45%;" />
#     <img src="..\figures\pricing_risk_02.png" style="width: 45%;" />
# </div>
#
# *   What drives the reaction of the stock markets to the increased tension between Israel and Iran?
#
# *   Why do the daily returns of indices differ such a great extent?
#
# *   What does an increase in the volatility index (VIX) mean for stocks? For the overall markets?
#
# ---

# %% [markdown]
# ### Capital markets and the pricing of risk
#
# <div style="display: flex; justify-content: space-around;">
#     <img src="..\figures\pricing_risk_03.png" style="width: 45%;" />
#     <img src="..\figures\pricing_risk_04.png" style="width: 45%;" />
# </div>
#
# *   What does the flight to quality mean?
#
# *   How would DXY index react to a flight to quality?
#
# *   Do the rising yields suggest a flight to quality?
#
# *   How would you expect the precious metal markets to be affected by these events?
#
# ---

# %% [markdown]
# ### Capital markets and the pricing of risk
#
# <div style="display: flex; justify-content: space-around;">
#     <img src="..\figures\pricing_risk_05.png" style="width: 45%;" />
#     <img src="..\figures\pricing_risk_06.png" style="width: 45%;" />
# </div>
#
# *   Why do we observe differing reactions of the consumer staples and consumer discretionary sub-indices?
#
# *   What are the potential drivers of these price moves and the differences?
#
# *   What do these observations imply regarding their riskiness vs. the SP500?
#
# ---

# %% [markdown]
# ### Capital markets and the pricing of risk
#
# <center>
# <img src="../figures/market_efficiency.png" width="640"/>
# </center>
#
# ---

# %% [markdown]
# ### Capital markets and the pricing of risk
#
# **The efficient markets hypothesis (EMH)**
#
# *   The weak-form hypothesis asserts that stock prices already reflect all information that can be derived by examining market trading data such as the history of past prices, trading volume, or short interest.
#
# *   The semistrong-form hypothesis states that all publicly available information regarding the prospects of a firm must be reflected already in the stock price.
#
# *   The strong-form version of the efficient market hypothesis states that stock prices reflect all information relevant to the firm, even including information available only to company insiders.
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# *   Probability Distributions
#
#     *   When an investment is risky, there are different returns it may earn.
#
#     *   Each possible return has some likelihood of occurring.
#
#     *   This information is summarized with a probability distribution, which assigns a probability, $P_R$, that each possible return, R, will occur.
#
# *   Expected Return
#
#     *   Given the probability distribution of returns, we can compute the expected return.
#
#     *   The expected (or mean) return as a weighted average of the possible returns, where the weights correspond to the probabilities.
#     $$ Expected\ Return = E[R] = \sum_R P_R * R $$
#
# | Current Stock Price ($) | Stock Price in One Year ($) | Return, R | Probability, $P_R$ |
# |---|---|---|---|
# | 100 | 140 | 0.40 | 25% |
# |   | 110 | 0.10 | 50% |
# |   | 80 | -0.20 | 25% |
#
# $$ Expected\ Return = E[R] = \sum_R P_R * R \quad \Rightarrow \quad E[R] = 25\%(-0.20) + 50\%(0.10) + 25\%(0.40) = 10\% $$
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# *   Variance and Standard Deviation
#     *   Variance: The expected squared deviation from the mean.
#     *   Standard Deviation: The square root of the variance.
#     $$ Var(R) = \sigma^2 = E[(R – E[R])^2] = \sum_R P_R \times (R - E[R])^2 $$
#     $$ SD(R) = \sigma = \sqrt{Var(R)} $$
#
# | Current Stock Price ($) | Stock Price in One Year ($) | Return, R | Probability, $P_R$ |
# |---|---|---|---|
# | 100 | 140 | 0.40 | 25% |
# |   | 110 | 0.10 | 50% |
# |   | 80 | -0.20 | 25% |
#
# $ Var[R] = 25\% \times (-0.20 - 0.10)^2 + 50\% \times (0.10 – 0.10)^2 + 25\% \times (0.40 – 0.10)^2 = 0.045 $
#
# $ SD(R) = \sqrt{Var(R)} = \sqrt{0.045} = 21.2\% $
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# *   Based on the following information, calculate the expected return and standard deviation for the two stocks:
#
#     | State of Economy | Probability of State of Economy | Rate of Return if State Occurs Stock A | Rate of Return if State Occurs Stock B |
#     |---|---|---|---|
#     | Recession | .30 | .06 | -.20 |
#     | Normal | .55 | .07 | .13 |
#     | Boom | .15 | .11 | .33 |
#
#     $$ Expected\ Return = E[R] = \sum_R P_R * R $$
#     $$ Var(R) = \sigma^2 = E[(R – E[R])^2] = \sum_R P_R \times (R - E[R])^2 $$
#     $$ SD(R) = \sigma = \sqrt{Var(R)} $$
#
#
#     | State of Economy | Probability of State of Economy | $R_A$ | $R_B$ | $P_i*(R_A-E(R_A))^2$ | $P_i*(R_B-E(R_B))^2$ |
#     |---|---|---|---|---|---|
#     | Recession | 30% | 6.00% | -20.00% | 0.0001 | 0.0204 |
#     | Normal | 55% | 7.00% | 13.00% | 0.0000 | 0.0026 |
#     | Boom | 15% | 11.00% | 33.00% | 0.0002 | 0.0109 |
#     | **E(Ri)** |  | **7.30%** | **6.10%** |  |  |
#     | **$\sigma^2$** |  |  |  | **0.000261** | **0.033909** |
#     | **$\sigma_i$** |  |  |  | **1.62%** | **18.41%** |
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# *   Computing Historical Returns
#
#     *   Realized Return: The return that actually occurs over a particular time period.
#     $$ R_{t+1} = \frac{Div_{t+1} + P_{t+1}}{P_t} - 1 = \frac{Div_{t+1}}{P_t} + \frac{P_{t+1} - P_t}{P_t} $$
#     $$ = Dividend\ Yield + Capital\ Gain\ Rate $$
#
#     *   This represents the total return over the (t, t+1) period.
#
#     *   When running an analysis using risk-return profiles always use the total return, not price return.
#
# *   Computing Historical Returns
#
#     *   Average Annual Returns: The return that actually occurs over a particular time period.
#     $$ \bar{R} = \frac{1}{T}(R_1 + R_2 + \dots + R_T) = \frac{1}{T}\sum_{t=1}^T R_t $$
#
#     *   Compound Annual Return: The geometric average of the annual returns $R_1, \dots, R_T$ :
#     $$ \bar{R}_G = [(1 + R_1) \times (1 + R_2) \times \dots \times (1 + R_T)]^{1/T} - 1 $$
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# *   Computing Historical Returns
#
#     *   Calculate the arithmetic and the geometric average annual returns for the set of returns given below.
#
#     | Year   | 1     | 2    | 3   | 4     | 5    |
#     |--------|-------|------|-----|-------|------|
#     | Return | -10%  | 15%  | 5%  | -15%  | 20%  |
#
#     $$ \bar{R} = \frac{1}{5}(-10\% + 15\% + 5\% - 15\% + 20\%) = 3\% $$
#     $$ \bar{R}_G = [(1 – 10\%) \times (1 + 15\%) \times (1+5\%) \times (1 - 15\%) \times (1 + 20\%)]^{1/5} – 1 = 2.08\% $$
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# *   Arithmetic vs. geometric average annual returns
#     *   The compound annual return will always be below the average return, and the difference grows with the volatility of the annual returns.
#
#     *   The compound annual return is a better description of the long-run historical performance of an investment. The ranking of the long-run performance of different investments coincides with the ranking of their compound annual returns.
#
#     *   When we are trying to estimate an investment's expected return over a future horizon based on its past performance, the arithmetic average return is superior to compound annual return.
#
#     *   If we view past returns as independent draws from the same distribution, then the arithmetic average return provides an unbiased estimate of the true expected return.
#
#         *   In doing so, we must compute the historical returns using the same time interval as the expected return we are estimating.
#             *   Use the average of past monthly returns to estimate the future monthly return,
#             *   Use the average of past annual returns to estimate the future annual return.
#             *   Avoid converting one to another using compounding.
#
# ---

# %% [markdown]
# ### Common Measures of Risk and Return
#
# <center>
# <img src="../figures/historical_risk_return.png" width="1080"/>
# </center>
#
# ---

# %% [markdown]
# ### Variance and Volatility of Returns
#
# **Variance estimate using realized returns**
#
# $$\sigma^2(R) = \frac{1}{T-1} \sum_{t=1}^{T} (R_t - \bar{R})^2$$
#
# **Estimation Error: Using Past Returns to Predict the Future**
#
# - We do not know what investors expected in the past; we can only observe the actual returns that were realized.
#
# - The average return is just an estimate of the true expected return, and it is subject to estimation error.
#
# **Standard Error**
#
# - Measures the estimation error of a statistical estimate.
#
# $$SE = \frac{\sigma(R)}{\sqrt{Number\ of\ Obs.}}$$
#
# - The average return will be within two SEs of the true E(R) approximately 95% of the time
#
# ---

# %% [markdown]
# ### Variance and Volatility of Returns
#
# * From 1926 to 2024 the average return of the S&P 500 was 9.8% with a volatility of 20.81%. Assuming its returns are IID each year, what is the 95% confidence interval for the expected return during this period?
#
#   * 95% confidence interval for the expected return: $\text{Historical Average Return} \pm (2 \cdot SE)$
#
# $$\text{Historical Average Return} \pm \left( 2 \cdot \frac{\sigma(R)}{\sqrt{n}} \right)$$
#
# $$9.8\% \pm \left( 2 \cdot \frac{20.81\%}{\sqrt{99}} \right) = 9.8\% \pm 4.10\% = [5.70\%, 13.90\%]$$
#
# * From 2005 to 2024 the average return of the S&P 500 was 11.87% with a volatility of 17.35%. Assuming its returns are IID each year, what is the 95% confidence interval for the expected return during this period?
#
#   * 95% confidence interval for the expected return: $\text{Historical Average Return} \pm (2 \cdot SE)$
#
# $$\text{Historical Average Return} \pm \left( 2 \cdot \frac{\sigma(R)}{\sqrt{n}} \right)$$
#
# $$11.87\% \pm \left( 2 \cdot \frac{17.35\%}{\sqrt{20}} \right) = 11.87\% \pm 7.60\% = [4.27\%, 19.47\%]$$
#
# ---

# %%
### Black Monday (1987)
import subprocess
import webbrowser
import os
from IPython.display import HTML
video_path = r"..\videos\Black_Monday.mp4"


def create_video_link(video_path):
    abs_path = os.path.abspath(video_path).replace('\\', '/')
    file_url = f"file:///{abs_path}"
    
    html = f"""
    <div style="border: 2px solid #ccc; padding: 20px; text-align: center;">
        <h3>Video: {os.path.basename(video_path)}</h3>
        <p>VS Code Jupyter blocks video controls. Click link to open in your default player:</p>
        
        <button onclick="window.open('{file_url}')" style="padding: 10px 20px; font-size: 16px;">
            Open Video
        </button>
    </div>
    """
    return HTML(html)

create_video_link(video_path)
# Out:
#     <div style="border: 2px solid #ccc; padding: 20px; text-align: center;">
#         <h3>Video: Black_Monday.mp4</h3>
#         <p>VS Code Jupyter blocks video controls. Click link to open in your default player:</p>
#
#         <button onclick="window.open('file:///c:/Users/Asus/My Drive/GitHubProjects/Financial_Tools_OFIN_SS2026/videos/Black_Monday.mp4')" style="padding: 10px 20px; font-size: 16px;">
#             Open Video
#         </button>
#     </div>

# %%
### 2008 Crash
import subprocess
import webbrowser
import os
from IPython.display import HTML

video_path = r"..\videos\2008_Crash.mp4"

def create_video_link(video_path):
    abs_path = os.path.abspath(video_path).replace('\\', '/')
    file_url = f"file:///{abs_path}"
    
    html = f"""
    <div style="border: 2px solid #ccc; padding: 20px; text-align: center;">
        <h3>Video: {os.path.basename(video_path)}</h3>
        <p>VS Code Jupyter blocks video controls. Click link to open in your default player:</p>
        
        <button onclick="window.open('{file_url}')" style="padding: 10px 20px; font-size: 16px;">
            Open Video
        </button>
    </div>
    """
    return HTML(html)

create_video_link(video_path)
# Out:
#     <div style="border: 2px solid #ccc; padding: 20px; text-align: center;">
#         <h3>Video: 2008_Crash.mp4</h3>
#         <p>VS Code Jupyter blocks video controls. Click link to open in your default player:</p>
#
#         <button onclick="window.open('file:///c:/Users/Asus/My Drive/GitHubProjects/Financial_Tools_OFIN_SS2026/videos/2008_Crash.mp4')" style="padding: 10px 20px; font-size: 16px;">
#             Open Video
#         </button>
#     </div>

# %% [markdown]
# ### Common Versus Independent Risk
# *   Common Risk (Systematic Risk)
#     *   Systematic risk is common to any risky asset in the financial market.
#     *   It is not diversifiable.
#     *   Wars, pandemic, natural disasters etc.
# *   Individual Risk (Idiosyncratic Risk)
#     *   Idiosyncratic risk is peculiar to the asset under consideration.
#     *   Diversifiable.
#     *   Problems with management, liquidity issues, regulatory changes, worker strikes etc.
# *   The averaging out of independent risks in a large portfolio is called diversification.
#
# <center>
# <img src="../figures/systematic_vs_idiosyncratic.png" width="640"/>
# </center>
#
# ---

# %% [markdown]
# ### Common Versus Independent Risk
#
# *   Suppose type S firms are affected only by the strength of the economy, which has a 50-50 chance of being either strong or weak. If the economy is strong, type S stocks will earn a return of 40%; if the economy is weak, their return will be -20%.
# *
#    On the other hand, type I firms are affected only by idiosyncratic. Their returns are equally likely to be 35% or -25%, based on factors specific to each firm's local market.
#
# *   What is the volatility of the average return of ten type S firms?
#
# *   What is the volatility of the average return of ten type I firms?
#
# $ E [R_S] = 50\% * 40\% + 50\% * -20\% = 10\% $
#
# $ SD(R_S) = \sqrt{0.5 * (40\% - 10\%)^2 + 0.5 * (-20\% - 10\%)^2} = 30\% $
#
#
# $ E [R_I] = 50\% * 35\% + 50\% * -25\% = 5\% $
#
# $ SD(R_I) = \sqrt{0.5 * (35\% – 5\%)^2 + 0.5 * (-25\% – 5\%)^2} = 30\% $
#
# *Volatility of the average return of ten type I firms:*
#
# $ SE = \frac{30\%}{\sqrt{10}} = 9.49\% $
#
# ---

# %% [markdown]
# ### Measuring Systematic Risk
# *   Investors can eliminate the firm-specific risk in their investments by diversifying their portfolio.
#     *   When evaluating the risk of an investment, an investor will care about its systematic risk, which cannot be eliminated through diversification.
#     *   In exchange for bearing systematic risk, investors require a higher return over risk-free interest rate. This is called the risk premium.
#
# *   The Market Portfolio
#     *   A portfolio of all stocks and securities traded in the capital markets.
#
# *   Efficient Portfolio
#     *   A portfolio that fluctuates solely due to systematic risk.
#     *   Cannot be diversified further.
#         *   There is no way to reduce the risk of the portfolio without lowering its expected return.
#
# *   Sensitivity to Systematic Risk: Beta ($\beta$)
#     *   Beta of a security is the sensitivity of that security's return to the return of the market portfolio
#
# ---

# %% [markdown]
# ### Measuring Systematic Risk
#
# *   Suppose the market portfolio tends to increase by 47% when the economy is strong and decline by 25% when the economy is weak.
#
#     *   What is the beta of a type S firm whose return is 40% on average when the economy is strong and -20% when the economy is weak?
#
#     *   What is the beta of a type I firm that bears only idiosyncratic, firm-specific risk?
#
#     Change in market return (Strong - Weak) = $47\% - (-25\%) = 72\%$
#
#     Change in type S firm return (Strong - Weak) = $40\% - (-20\%) = 60\%$
#
#     $$ \beta_S = \frac{\text{Change in S return}}{\text{Change in market return}} = \frac{60\%}{72\%} = 0.833 $$
#
#     $$ \beta_I = 0 $$
#
# ---

# %% [markdown]
# ### Risk Aversion and the Cost of Capital
#
# *   For risky investments, the cost of capital exceeds the risk-free interest rate ($r_f$) because risk-averse investors require additional compensation for bearing uncertainty.
#
# *   The size of this compensation, or risk premium, depends on investors’ degree of risk aversion and on the type of risk the investment adds to a diversified portfolio.
#
#     *   **Risk Aversion:** A preference for a certain outcome over a risky outcome with the same expected payoff.
#
#     *   **Example:** Consider a lottery ticket with a 1% chance of winning $100 and a 99% chance of winning $0. The expected value is exactly $1.
#
#         *   **Risk-Neutral Investor:** Is indifferent between a certain $1 and the lottery ticket. They care only about the expected value and do not require a premium for risk.
#
#         *   **Risk-Averse Investor:** Prefers a certain $1 over the ticket. To accept the risk, they would only buy the ticket at a price below $1, or equivalently, would require a higher expected payoff to be induced to hold it.
#
#         *   **Risk-Seeking Investor:** Enjoys the gamble and may be willing to pay more than the $1 expected value for the chance to win.
#
# *   In financial markets, investors are generally assumed to be risk-averse. Consequently, risky assets must offer higher expected returns than risk-free assets to be willingly held.
#
# ---

# %% [markdown]
# ### Beta and the Cost of Capital
#
# *   The Market Risk Premium
#     $$ Market\ Risk\ Premium = E[R_{Mkt}] - r_f $$
#     *   The market interest rate reflects investors' patience and determines the time value of money.
#
#     *   The market risk premium reflects investors' risk tolerance and determines the market price of risk in the economy.
#
# *   Estimating the Cost of Capital of an Investment from Its Beta
#
#     $ E[R_i] = r_f + \beta_i * Market\ Risk\ Premium $
#     $ E[R_i] = r_f + \beta_i * (E[R_{Mkt}] – r_f) $
#
#     *   Firms A and B have betas of 0.80 and 1.25, respectively. If the market risk premium is 5% and the risk-free interest rate is 4%, estimate the equity cost of capital for each of these firms.
#
#     $ E[R_A] = r_f + \beta_A * (E[R_{Mkt}] - r_f) = 4\% + 0.80 * 5\% = 8\% $
#
#     $ E[R_B] = r_f + \beta_B * (E[R_{Mkt}] - r_f) = 4\% + 1.25 * 5\% = 10.25\% $
#
# ---

# %% [markdown]
# ### Exercise 7.1
#
# An analyst is comparing the performance of two investment portfolios, "Portfolio Omega" and "Portfolio Sigma". Using the following historical annual returns, calculate the average return, the variance, and the standard deviation for each portfolio.
#
# | Year | Portfolio Omega | Portfolio Sigma |
# |:----:|:---------------:|:---------------:|
# | 1    | 12.0%           | 22.0%           |
# | 2    | 18.0%           | -8.0%           |
# | 3    | -5.0%           | 28.0%           |
# | 4    | 15.0%           | 2.0%            |
# | 5    | 10.0%           | 16.0%           |
#
# ---

# %% [markdown]
# ### Exercise 7.1: Solution
#
#
# $$\bar r_O = \frac{12+18-5+15+10}{5} = 10.00\%$$
#
# $$s_O^2 = \frac{\sum(r_i - \bar r_O)^2}{n-1} = \frac{4 + 64 + 225 + 25 + 0}{4} = 79.50$$
#
# $$s_O = \sqrt{79.50} = 8.92\%$$
#
# $$\bar r_S = \frac{22-8+28+2+16}{5} = 12.00\%$$
#
# $$s_S^2 = \frac{\sum(r_i - \bar r_S)^2}{n-1} = \frac{100 + 400 + 256 + 100 + 16}{4} = 218.00$$
#
# $$s_S = \sqrt{218.00} = 14.76\%$$
#
# ---

# %% [markdown]
# ### Exercise 7.2
#
# An investor is evaluating the "Horizon Alpha Fund," which has reported the following annual returns over the last five years: 15.4%, -8.2%, 22.5%, 11.0%, and 16.8%.
#
# *   What is the total cumulative return of the fund over the entire five-year period?
#
# *   What is the compound average annual growth rate (CAGR) of the fund?
#
# ---

# %% [markdown]
# ### Exercise 7.2: Solution
#
# $$
# \text{Cumulative factor} = 1.154 \times 0.918 \times 1.225 \times 1.11 \times 1.168 = 1.68248
# $$
#
# $$
# \text{Cumulative return} = 1.68248 - 1 = 0.68248 = 68.25\%.
# $$
#
# $$
# \text{CAGR} = (1.68248)^{1/5} - 1 = 0.10967 = 10.97\%.
# $$
#
#
# ---

# %% [markdown]
# ### Exercise 7.3
#
# An investor is analyzing a mutual fund's performance over a five-year period. The fund's historical Net Asset Value (NAV) at the end of each year and the dividend distributions paid out during the year are provided below. Calculate the arithmetic and geometric mean annual returns for this fund.
#
# | Year | NAV    | Distribution |
# |:----:|:------:|:------------:|
# | 0    | $40.00 | $0.00        |
# | 1    | $44.80 | $1.20        |
# | 2    | $42.00 | $1.30        |
# | 3    | $50.40 | $1.40        |
# | 4    | $62.00 | $1.50        |
# | 5    | $65.00 | $1.60        |
#
# ---

# %% [markdown]
# ### Exercise 7.3: Solution
#
# $$
# \begin{aligned}
# R_1 &= \frac{44.80 - 40.00 + 1.20}{40.00} = 0.150000 \\
# R_2 &= \frac{42.00 - 44.80 + 1.30}{44.80} \approx -0.033482 \\
# R_3 &= \frac{50.40 - 42.00 + 1.40}{42.00} \approx 0.233333 \\
# R_4 &= \frac{62.00 - 50.40 + 1.50}{50.40} \approx 0.259921 \\
# R_5 &= \frac{65.00 - 62.00 + 1.60}{62.00} \approx 0.074194
# \end{aligned}
# $$
#
# $$
# \text{Arithmetic Mean } (\bar R) = \frac{0.150000 - 0.033482 + 0.233333 + 0.259921 + 0.074194}{5} \approx 13.68\%
# $$
#
# $$
# \begin{aligned}
# R_{\text{geo}} &= \Bigl[(1+R_1)(1+R_2)(1+R_3)(1+R_4)(1+R_5)\Bigr]^{1/5} - 1 \\
#                &\approx (1.855299)^{1/5} - 1 \\
#                &\approx 0.131574 = 13.16\%
# \end{aligned}
# $$
# ---

# %% [markdown]
# ### Exercise 7.4
#
# A business analyst is reviewing the performance of "Urban Trend Electronics," a retail chain. The company's annual revenue growth over the last five years was as follows: 12%, 7%, -5%, 18%, and 13%.
#
# *   What is the arithmetic average annual growth for the company over this five-year period?
#
# *   What are the variance and the standard deviation of the company's annual growth rates over this period?
#
# ---

# %% [markdown]
# ### Exercise 7.4: Solution
#
# | Year | Growth $g_t$ | $g_t-\bar g$ | $(g_t-\bar g)^2$ |
# |-----:|-------------:|-------------:|-----------------:|
# | 1 | 12.00 % | 3.00 % | 0.000900 |
# | 2 | 7.00 % | −2.00 % | 0.000400 |
# | 3 | −5.00 % | −14.00 %| 0.019600 |
# | 4 | 18.00 % | 9.00 % | 0.008100 |
# | 5 | 13.00 % | 4.00 % | 0.001600 |
# | **Totals** | — | — | 0.030600 |
#
# $\bar g = 9.00\% \quad\;\; s^2 = 0.00765 \;(\text{variance}) \quad\;\; s = 8.75\% \;(\text{standard deviation})$
#
# ---

# %% [markdown]
# ### Exercise 7.5
#
# An analyst is evaluating two different investment funds: a "Stable Income Fund" and a "Dynamic Equity Fund." The potential returns for these funds depend on the future state of the economy. Based on the following forecast, calculate the expected return and the standard deviation for each fund.
#
# | State of Economy | Probability of State | Stable Income Fund Return | Dynamic Equity Fund Return |
# |:----------------:|:--------------------:|:-------------------------:|:--------------------------:|
# | Recession        | 25%                  | 4.0%                      | -15.0%                     |
# | Normal Growth    | 55%                  | 8.0%                      | 20.0%                      |
# | Rapid Expansion  | 20%                  | 10.0%                     | 35.0%                      |
#
# ---

# %% [markdown]
# ### Exercise 7.5: Solution
#
# Expected returns
#
# $$E[R_S]=0.25(0.04)+0.55(0.08)+0.20(0.10)=0.074=7.40\%$$
#
# $$E[R_D]=0.25(-0.15)+0.55(0.20)+0.20(0.35)=0.1425=14.25\%$$
#
# Variances
#
# $$\sigma_S^{2}=0.25(0.04-0.074)^2+0.55(0.08-0.074)^2+0.20(0.10-0.074)^2=0.000444$$
#
# $$\sigma_D^{2}=0.25(-0.15-0.1425)^2+0.55(0.20-0.1425)^2+0.20(0.35-0.1425)^2=0.03181875$$
#
# Standard deviations
#
# $$\sigma_S=\sqrt{0.000444} \approx 0.0211 = 2.11\%$$
#
# $$\sigma_D=\sqrt{0.03181875} \approx 0.1784 = 17.84\%$$
#
# ---

# %% [markdown]
# ### Exercise 7.6
#
# Consider an economy with two types of firms, Sigma and Omega. Sigma firms all move together due to common market-wide factors (perfectly correlated). Omega firms move independently of each other (zero correlation). For any firm of either type, there is a 60% probability that it will have a 25% return and a 40% probability that it will have a -10% return.
#
# *   What is the volatility (standard deviation) of a portfolio that consists of an equal investment in 30 firms of type Sigma?
#
# *   What is the volatility of a portfolio that consists of an equal investment in 30 firms of type Omega?
#
#
# ---

# %% [markdown]
# ### Exercise 7.6: Solution
#
# $$
# \begin{aligned}
# E[r] &= 0.6(0.25) + 0.4(-0.10) = 0.11 \\[4pt]
# \operatorname{Var}(r) &= 0.6(0.25 - 0.11)^2 + 0.4(-0.10 - 0.11)^2 = 0.0294 \\[4pt]
# \sigma &= \sqrt{0.0294} \approx 0.1715 \;(17.15\%)
# \end{aligned}
# $$
#
# **30-firm Sigma portfolio:**
# Since Sigma firms are perfectly correlated, the portfolio volatility is identical to the volatility of a single firm.
#
# $$\sigma_{30,\text{Sigma}} = 17.15\%$$
#
# **30-firm Omega portfolio:**
# Since Omega firms are independent, the portfolio variance is the individual variance divided by the number of firms ($n=30$).
#
# $$
# \operatorname{Var}(R_p) = \frac{\operatorname{Var}(r)}{30} = \frac{0.0294}{30} = 0.00098
# $$
#
# $$
# \sigma_{30,\text{Omega}} = \sqrt{0.00098} \approx 0.0313 \;(3.13\%)
# $$
#
# ---

# %% [markdown]
# ### Exercise 7.7
#
# An investor with an initial capital of $20,000 is considering two strategies for a two-year investment horizon. The investor can use a risk-free asset with a guaranteed annual return of 3%. Alternatively, they can invest in a "High-Volatility Stock," which is projected to return either 35% (in a growth state) or -10% (in a recession state) each year, with a 50% probability for each outcome.
#
# The two strategies are:
#
# 1.  Invest the entire $20,000 for one year in the risk-free asset, then reinvest the full amount for the second year in the High-Volatility Stock.
#
# 2.  Invest the entire $20,000 for both years in the High-Volatility Stock.
#
# *   Which strategy results in a higher expected final wealth?
#
# *   Which strategy has the greater standard deviation of final wealth, indicating higher risk?
#
#
# ---

# %% [markdown]
# ### Exercise 7.7: Solution
#
# **Strategy 1 (Year 1 risk-free, Year 2 Stock)**
#
# Year-1 wealth: $20,000 \times (1 + 0.03) = \$20,600$
#
# Year-2 outcomes:
# *   **Growth:** $\$20,600 \times (1 + 0.35) = \$27,810$
# *   **Recession:** $\$20,600 \times (1 - 0.10) = \$18,540$
#
# Expected final wealth: $E[W_1] = 0.5(\$27,810) + 0.5(\$18,540) = \$23,175$
#
# $$ \sigma_1^2 = 0.5(27,810 - 23,175)^2 + 0.5(18,540 - 23,175)^2 = 21,483,225 \quad \Rightarrow \quad \sigma_1 = \sqrt{21,483,225} \approx \$4,635 $$
#
# **Strategy 2 (Stock both years)**
#
# | Path | Probability | Wealth Calculation | Wealth |
# | :--- | :---: | :--- | :---: |
# | Growth-Growth | 0.25 | $20,000 \times (1.35)^2$ | $36,450 |
# | Growth-Recess | 0.25 | $20,000 \times (1.35)(0.90)$ | $24,300 |
# | Recess-Growth | 0.25 | $20,000 \times (0.90)(1.35)$ | $24,300 |
# | Recess-Recess | 0.25 | $20,000 \times (0.90)^2$ | $16,200 |
#
# Expected final wealth: $E[W_2] = 0.25(36,450 + 24,300 + 24,300 + 16,200) = \$25,312.50$
#
# $$ \sigma_2^2 = 0.25[(36,450 - 25,312.5)^2 + 2(24,300 - 25,312.5)^2 + (16,200 - 25,312.5)^2] = 51,890,625 $$
# $$ \sigma_2 = \sqrt{51,890,625} \approx \$7,203.51 $$
#
# **Strategy 2 results in a higher expected final wealth but also carries significantly higher risk (standard deviation).**
#
# ---

# %% [markdown]
# ### Exercise 7.8
#
# *   An asset has a beta of 1.40. If the expected return on the market is 12% and the risk-free rate is 4%, what is the expected return for the asset?
#
# *   An asset has an expected return of 13% and the risk-free rate is 3%. If the market risk premium is 8%, what is the beta of the asset?
#
# *   An asset has an expected return of 15%, a beta of 1.25, and the risk-free rate is 6%. According to CAPM, what is the expected return on the market?
#
# *   An asset is priced to have an expected return of 10% and has a beta of 0.75. If the expected return on the market is 11%, what is the risk-free rate?
#
#
# ---

# %% [markdown]
# ### Exercise 7.8: Solution
# Using CAPM: $E[R_i] = R_f + \beta(E[R_m] - R_f)$
#
#
# $$E[R_i] = 4 + 1.40(12 - 4) = 15.20\%$$
#
#
# $$\beta = \frac{E[R_i] - R_f}{\text{Market Risk Premium}} = \frac{13 - 3}{8} = 1.25$$
#
#
# $$15 = 6 + 1.25(E[R_m] - 6) \Rightarrow 9 = 1.25(E[R_m] - 6) \Rightarrow E[R_m] = 13.20\%$$
#
#
# $$10 = R_f + 0.75(11 - R_f) \Rightarrow 10 = 0.25R_f + 8.25 \Rightarrow R_f = 7.00\%$$
#
# ---

# %% [markdown]
# ### Exercise 7.9
#
# Assume the overall market portfolio has a 50% chance of returning 28% (an "Expansion" state) and a 50% chance of returning -8% (a "Recession" state).
#
# *   Calculate the beta of Stock X, which is expected to return 40% in an Expansion and -20% in a Recession.
#
# *   Calculate the beta of Stock Y, which is expected to return -8% in an Expansion and 28% in a Recession. This type of stock is often called a "defensive" or "counter-cyclical" asset.
#
# *   Calculate the beta of Stock Z, which is expected to yield a constant 4% return regardless of the market's performance.
#
#
# ---

# %% [markdown]
# ### Exercise 7.9: Solution
#
# $E[R_M] = 0.5(0.28) + 0.5(-0.08) = 0.10$
#
# $\text{Var}(R_M) = 0.5(0.28 - 0.10)^2 + 0.5(-0.08 - 0.10)^2 = 0.0324$
#
# $\beta_i = \dfrac{\text{Cov}(R_i, R_M)}{\text{Var}(R_M)}$
#
# **Stock X:**
# $\text{Cov}(R_X, R_M) = 0.5(0.40 - 0.10)(0.28 - 0.10) + 0.5(-0.20 - 0.10)(-0.08 - 0.10) = 0.054$
# $\beta_X = \dfrac{0.054}{0.0324} \approx 1.67$
#
# **Stock Y:**
# $\text{Cov}(R_Y, R_M) = 0.5(-0.08 - 0.10)(0.28 - 0.10) + 0.5(0.28 - 0.10)(-0.08 - 0.10) = -0.0324$
# $\beta_Y = \dfrac{-0.0324}{0.0324} = -1.00$
#
# **Stock Z:**
# Constant return of 0.04 $\Rightarrow \text{Cov}(R_Z, R_M) = 0 \Rightarrow \beta_Z = 0$
#
#
#
# ---

# %% [markdown]
# ### What is next?
#
# *   Risk and Return
#     *   Optimal Portfolio Choice
#     *   The Capital Asset Pricing Model
#     *   Reading(s):
#         *   CF-B&D: Ch. 11
#
# ---
